# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading dataset
df = pd.read_csv(r"C:\Users\HP\Downloads\Wine_clust .csv")

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %% [markdown]
# Data Analysis

# %%
df.shape
# Out:
# (178, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %% [markdown]
# ### outliers

# %%
num_cols = ['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
       'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
       'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline']
for i in num_cols:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)

# %%
cols = ['Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium','Proanthocyanins', 'Color_Intensity', 'Hue']

for i in cols:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    low_lim = Q1 -(1.5*IQR)
    up_lim = Q3 +(1.5*IQR)
    df[i]=np.where(df[i]>up_lim,up_lim,np.where(df[i]<low_lim,low_lim,df[i]))

# %%
for i in num_cols:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(i)

# %% [markdown]
# ### correlation

# %%
df.corr(method='pearson')
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094756  0.220174     -0.312191   0.302173
# Malic_Acid            0.094756    1.000000  0.166614      0.295882  -0.039329
# Ash                   0.220174    0.166614  1.000000      0.427713   0.322510
# Ash_Alcanity         -0.312191    0.295882  0.427713      1.000000  -0.098030
# Magnesium             0.302173   -0.039329  0.322510     -0.098030   1.000000
# Total_Phenols         0.289101   -0.339050  0.124436     -0.333046   0.227035
# Flavanoids            0.236815   -0.414875  0.097562     -0.363405   0.209431
# Nonflavanoid_Phenols -0.155929    0.294203  0.183666      0.369276  -0.255674
# Proanthocyanins       0.153171   -0.234575  0.006080     -0.208794   0.201428
# Color_Intensity       0.549107    0.264897  0.256799      0.009748   0.240505
# Hue                  -0.067156   -0.566409 -0.075904     -0.286664   0.040007
# ...

# %%
corr_graph = df.corr()
plt.subplots(figsize=(10,8))
sns.heatmap(corr_graph, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### scaling

# %%
#Standard scaling
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X = std.fit_transform(df)

# %% [markdown]
# ## Principal Component Analysis(PCA)

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(X)

plt.rcParams["figure.figsize"] = (12,6)

fig, ax = plt.subplots()

xi = np.arange(1, 14, step=1)

y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')
plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 14, step=1))
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')
plt.axhline(y=0.97, color='r', linestyle='-')
plt.text(0.5, 0.85, '97% cut-off threshold', color = 'red', fontsize=16)
ax.grid(axis='x')
plt.show()

# %%
# doing PCA
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.97)
pca.fit(X)
x_pca = pca.transform(X)
x_pca.shape
# Out:
# (178, 11)

# %% [markdown]
# ## K Means

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

labels_kmeans = kmeans.labels_
df['Cluster'] = labels_kmeans

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1', marker = 'o')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2', marker = 'o')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3', marker = 'o')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4', marker = 'o')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5', marker = 'o')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ## Heirarchical

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Dendrograms")
dend = shc.dendrogram(shc.linkage(X,method='ward'))
plt.axhline(y=20, color = 'r', linestyle = '--')

# %% [markdown]
# ## Aggloromative

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', 
                                  linkage='ward')
y_agg = cluster.fit_predict(X)
labels_agg = cluster.labels_
labels_hc = cluster.labels_

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=3, min_samples=4, metric='euclidean')

# %%
y_db = db.fit(X)
labels_db =y_db.labels_

# %% [markdown]
# ### models evaluation

# %%
from sklearn import metrics 
print("KMeans Silhouette Score: ", 
      metrics.silhouette_score(X,labels_kmeans, metric = 'euclidean'))
print("HC Silhouette Score: ", 
      metrics.silhouette_score(X,labels_hc, metric = 'euclidean'))
print("Agglomorative Silhouette Score: ", 
      metrics.silhouette_score(X,labels_agg, metric = 'euclidean'))
print("DBSCAN Silhouette Score: ", 
      metrics.silhouette_score(X,labels_db, metric = 'euclidean'))
# Out:
# KMeans Silhouette Score:  0.2854626783251893
# HC Silhouette Score:  0.2786997668206731
# Agglomorative Silhouette Score:  0.2786997668206731
# DBSCAN Silhouette Score:  0.18543114204572875
