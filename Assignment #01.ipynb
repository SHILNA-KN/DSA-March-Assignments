# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1.Read the dataset to python environment

# %%
data=pd.read_excel(r'C:\Users\HP\Downloads\iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 2.Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #### 3.Calculate the mean of each column of the dataset.

# %%
data.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8732\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# #### 4.Check for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# #### 5.Perform meaningful visualizations using the dataset.

# %% [markdown]
# ### 1.Bar plot

# %%
plt.bar(data['Classification'],data['SL'])
plt.title('Iris Classification with SL')
plt.ylabel('SL')
plt.show()

# %%
plt.bar(data['Classification'],data['PL'])
plt.title('Iris classification with PL')
plt.ylabel('PL')
plt.show()

# %% [markdown]
# ### 2.Pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ### 3. Boxplot

# %%
plt.boxplot(data['SL'])
plt.show()

# %% [markdown]
# ### 4.Countplot

# %%
sns.countplot(x=data.PW)
plt.show()

# %% [markdown]
# ### 5.Scatterplot

# %%
plt.scatter(data['SL'],data['SW'],s=10,color='blue')

# %% [markdown]
# ### 6. Histogram

# %%
plt.figure(figsize=(10,5))
plt.hist(data['PW'],color='green',rwidth=0.98,cumulative=True)
plt.title('histogram of PW',fontsize=20)
plt.xlabel('PW')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
